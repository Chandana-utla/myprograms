# %% [markdown]
# matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([1,2])
ypoints=np.array([5,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,20])
ypoints=np.array([10,200])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,6])
ypoints=np.array([4,5])
plt.plot(xpoints,ypoints,"*")
plt.show()

# %%
ypoints = np.array([3,8,1,10])

plt.plot(ypoints, '*''r')
plt.show()

# %%
ypoints=np.array([3,8,1,12])
xpoints=np.array([5,6,7,12])
plt.plot(xpoints,ypoints,marker="*",ms=10,color='pink')
plt.show()

# %%
ypoints=np.array([3,8,1])

plt.plot(ypoints,marker='o',ms=50,mec='b',color='pink')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,marker='o',ms=20,mfc='r',mec='k')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,marker='o',ms=200,mfc='k',mec='y')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linestyle='dashed',marker='o',ms=20,mfc='blue',mec='hotpink',linewidth=10)
plt.show()

# %%
plt.plot(ypoints,linestyle='dotted',marker='o',ms=20,mfc='blue',mec='hotpink',linewidth=10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([1,2])
ypoints=np.array([5,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
plt.plot(ypoints,linestyle='dotted',marker="o",ms=25,mfc="green",mec="red")

# %%
xpoints=np.array([10,20,30])
ypoints=np.array([1,2,6])
plt.plot(xpoints,ypoints,marker="*",color="g",mfc="b",mec="r",ms=50,linestyle="dotted")

# %%
ypoints=np.array([3,8,1,10])
xpoints=np.array([2,4,6,8])
plt.plot(xpoints,ypoints,linewidth=1,linestyle="dotted",color="red",marker="o",ms=20,mec= "g")
plt.show()

# %%
y1=np.array([3,8,1,10])
y2=np.array([6,2,5,11,10,12])
plt.plot(y1,color="k",marker="*")
plt.plot(y2,color="r")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,color="r",linewidth=1)
plt.xlabel("Average Pulse",fontsize=10,color="red")
plt.ylabel("Calorie Burnage",fontsize=10,color="blue")
plt.title("sample",fontsize=50,color="blue")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
 
plt.title("Sports watch data",fontsize=20,color="green",loc="left")
plt.xlabel("Average Pulse",loc="right")
plt.ylabel("Calorie Burnage",loc="top")
plt.plot(x,y)

plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,color="r",linewidth=1)

plt.xlabel("Average Pulse",fontsize=10,color="red",loc="left")
plt.ylabel("Calorie Burnage",fontsize=50,color="blue")
plt.title("sample",fontsize=50,color="blue")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,95,100,105,110,115,120,125])
plt.plot(x,y,color="r",linewidth=1)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("sample")
plt.grid(color="green",linestyle="dotted")
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("Sports watch data")

plt.plot(x,y)
plt.grid(axis='x')
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("Sports watch data")

plt.plot(x,y)
plt.grid(axis='y')
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("Sports watch data")

plt.plot(x,y)
plt.grid(color='hotpink',linestyle='--',linewidth=1.5)
plt.show()

# %% [markdown]
# scatter plot-to find realtion between two numerical attributes

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,95,100,105,110,115,120,125])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)


x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,color='hotpink')


x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y,color='green')
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,color="black")
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y,color="black")
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y,color="green")
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,width=0.05)
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y,height=0.1)
plt.show()

# %%
x=np.random.normal(15,5,1000)

# %%
plt.hist(x)
# Out:
# (array([  1.,  13.,  51., 138., 207., 280., 187.,  91.,  23.,   9.]),
#  array([-3.32194397,  0.11300249,  3.54794894,  6.9828954 , 10.41784185,
#         13.85278831, 17.28773476, 20.72268122, 24.15762768, 27.59257413,
#         31.02752059]),
#  <BarContainer object of 10 artists>)

# %%
x=np.random.normal(100,5,2500)

# %%
plt.hist(x)
plt.show()

# %%
y=np.array([10,135,25,15,19])
plt.pie(y)
plt.show()

# %%
y=np.array([10,25,15,10])
mylabels=["Cherries","Apples","Bananas","Dates"]

plt.pie(y,labels=mylabels)
plt.show()

# %%
y=np.array([10,25,15,10])
mylabels=["Cherries","Apples","Bananas","Dates"]

plt.pie(y,labels=mylabels,startangle=90)
plt.show()

# %%
y=np.array([10,25,15,10])
mylabels=["Cherries","Apples","Bananas","Dates"]
myexplode=[0,0.95,0.8,0.2]

plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=["Cherries","Apples","Bananas","Dates"]
myexplode=[0,0.95,0.8,0.2]

plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=["Cherries","Apples","Bananas","Dates"]
mycolors=["black","hotpink","b","yellow"]
myexplode=[0,0.95,0.8,0.2]

plt.pie(y,labels=mylabels,colors=mycolors,startangle=180)
plt.show()

# %%
y=np.array([35,25,25,15])

plt.pie(y)
plt.legend(labels=mylabels)
plt.show()
